# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!') # the letter P is in capital letter. We change the capital letter P into small letter p.
# Out:
# Hello world!

# %%
print('Hello world!') #missing open parenthesis"(". we add open parenthesis
# Out:
# Hello world!

# %%
print('Hello world!')# missing one quotation ('). we add one quotation
# Out:
# Hello world!

# %%
print('Hello world!')#morethan one quotation ('). we eleminate one quotation
# Out:
# Hello world!

# %% [markdown]
# #### Exercise 2
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)#44
# Out:
# 44

# %% [markdown]
# #### Exercise 3
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1
print(x)#the formula which is one of the "X" is in capital letter. we change capital letter X into small capital letter
# Out:
# 44
